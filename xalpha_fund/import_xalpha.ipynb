# %% [markdown]
# # `xalpha` 基金投资的全流程管理
#
# - [ ] Setup Github reposiry 怎么获取实时的数据？
#
# 场外基金的信息与净值获取，精确到分的投资账户记录整合分析与丰富可视化，简单的策略回测以及根据预设策略的定时投资提醒。尤其适合资金反复进出的定投型和网格型投资的概览与管理分析。
#
# 🎉 0.3 版本起支持通用日线和实时数据获取器，统一接口一行可以获得几乎任何市场上存在产品的价格数据，进行分析。
#
# 🍭 0.9 版本起支持持仓基金组合的底层持仓配置和股票细节透视，掌握底层持仓和跟踪机构股票池与买卖特点，从未如此简单。

# %%
import xalpha as xa
# xalpha in /Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages (0.11.4)

# %%
from sqlalchemy import create_engine
import pymysql
engine = create_engine('mysql+pymysql://root:password@127.0.0.1/database?charset=utf8')
io = {"save": True, "fetch": True, "form": "sql", "path": engine}

# %% [markdown]
# ## connecting to MySQL
# The MySQL dialect uses mysql-python as the default DBAPI. There are many MySQL DBAPIs available, including MySQL-connector-python and OurSQL:

# %%
# default
engine = create_engine('mysql://scott:tiger@localhost/foo')

# mysqlclient (a maintained fork of MySQL-Python)
engine = create_engine('mysql+mysqldb://scott:tiger@localhost/foo')

# PyMySQL
engine = create_engine('mysql+pymysql://scott:tiger@localhost/foo')

# %%
xa.fundinfo("510018", **io)
yfd_zhongzhen500_c = xa.fundinfo('007029') #易方达中证500ETF联接C
# Out:
# Fails at fetching url: http://fund.eastmoney.com/pingzhongdata/510018.js. Try again.
# Fails at fetching url: http://fund.eastmoney.com/pingzhongdata/510018.js. Try again.
# Fails at fetching url: http://fund.eastmoney.com/pingzhongdata/510018.js. Try again.
# Fails at fetching url: http://fund.eastmoney.com/pingzhongdata/510018.js. Try again.
# Fails at fetching url: http://fund.eastmoney.com/pingzhongdata/510018.js. Try again.
# Still wrong at fetching url: http://fund.eastmoney.com/pingzhongdata/510018.js. after 5 tries.
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py:613, in Connection.connect(self, sock)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=611'>612</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=612'>613</a>     sock = socket.create_connection(
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=613'>614</a>         (self.host, self.port), self.connect_timeout, **kwargs
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=614'>615</a>     )
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=615'>616</a>     break
#
# File ~/opt/anaconda3/lib/python3.8/socket.py:808, in create_connection(address, timeout, source_address)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/socket.py?line=806'>807</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/socket.py?line=807'>808</a>     raise err
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/socket.py?line=808'>809</a> finally:
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/socket.py?line=809'>810</a>     # Break explicitly a reference cycle
#
# File ~/opt/anaconda3/lib/python3.8/socket.py:796, in create_connection(address, timeout, source_address)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/socket.py?line=794'>795</a>     sock.bind(source_address)
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/socket.py?line=795'>796</a> sock.connect(sa)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/socket.py?line=796'>797</a> # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3278'>3279</a> try:
# -> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3279'>3280</a>     return fn()
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3280'>3281</a> except dialect.dbapi.Error as e:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=302'>303</a> """Return a DBAPI connection from the pool.
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=303'>304</a>
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=304'>305</a> The connection is instrumented such that when its
#    (...)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=307'>308</a>
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=308'>309</a> """
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=309'>310</a> return _ConnectionFairy._checkout(self)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=866'>867</a> if not fairy:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=867'>868</a>     fairy = _ConnectionRecord.checkout(pool)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=869'>870</a>     fairy._pool = pool
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=473'>474</a> @classmethod
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=474'>475</a> def checkout(cls, pool):
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=475'>476</a>     rec = pool._do_get()
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=476'>477</a>     try:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=144'>145</a>         with util.safe_reraise():
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=145'>146</a>             self._dec_overflow()
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=146'>147</a> else:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=68'>69</a>     if not self.warn_only:
# ---> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=69'>70</a>         compat.raise_(
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=70'>71</a>             exc_value,
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=71'>72</a>             with_traceback=exc_tb,
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=72'>73</a>         )
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=73'>74</a> else:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=206'>207</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=207'>208</a>     raise exception
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=208'>209</a> finally:
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # credit to
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     # as the __traceback__ object creates a cycle
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=141'>142</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=142'>143</a>     return self._create_connection()
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=143'>144</a> except:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=253'>254</a> """Called by subclasses to create a new ConnectionRecord."""
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=255'>256</a> return _ConnectionRecord(self)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=369'>370</a> if connect:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=370'>371</a>     self.__connect()
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=371'>372</a> self.finalize_callback = deque()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:666, in _ConnectionRecord.__connect(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=664'>665</a>     with util.safe_reraise():
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=665'>666</a>         pool.logger.debug("Error on connect(): %s", e)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=666'>667</a> else:
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=667'>668</a>     # in SQLAlchemy 1.4 the first_connect event is not used by
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=668'>669</a>     # the engine, so this will usually not be set
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=68'>69</a>     if not self.warn_only:
# ---> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=69'>70</a>         compat.raise_(
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=70'>71</a>             exc_value,
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=71'>72</a>             with_traceback=exc_tb,
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=72'>73</a>         )
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=73'>74</a> else:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=206'>207</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=207'>208</a>     raise exception
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=208'>209</a> finally:
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # credit to
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     # as the __traceback__ object creates a cycle
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:661, in _ConnectionRecord.__connect(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=659'>660</a> self.starttime = time.time()
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=660'>661</a> self.dbapi_connection = connection = pool._invoke_creator(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=661'>662</a> pool.logger.debug("Created new connection %r", connection)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py:590, in create_engine.<locals>.connect(connection_record)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py?line=588'>589</a>             return connection
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py?line=589'>590</a> return dialect.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=594'>595</a> def connect(self, *cargs, **cparams):
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=595'>596</a>     # inherits the docstring from interfaces.Dialect.connect
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=596'>597</a>     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py:353, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=351'>352</a> else:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=352'>353</a>     self.connect()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py:664, in Connection.connect(self, sock)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=662'>663</a>         print(exc.traceback)
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=663'>664</a>     raise exc
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=665'>666</a> # If e is neither DatabaseError or IOError, It's a bug.
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=666'>667</a> # But raising AssertionError hides original error.
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=667'>668</a> # So just reraise it.
#
# OperationalError: (2003, "Can't connect to MySQL server on '127.0.0.1' ([Errno 61] Connection refused)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py:345, in basicinfo.__init__(self, code, fetch, save, path, form, round_label, dividend_label, value_label)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=343'>344</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=344'>345</a>     self.fetch(path, self.format)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=345'>346</a>     df = self.update()  # update the price table as well as the file
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py:494, in basicinfo.fetch(self, path, form)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=492'>493</a> elif form == "sql":
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=493'>494</a>     self._fetch_sql(path)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py:887, in fundinfo._fetch_sql(self, path)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=885'>886</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=886'>887</a>     content = pd.read_sql("xa" + self.code, path)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=887'>888</a>     pricetable = content.iloc[1:]
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py:592, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=590'>591</a> else:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=591'>592</a>     return pandas_sql.read_query(
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=592'>593</a>         sql,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=593'>594</a>         index_col=index_col,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=594'>595</a>         params=params,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=595'>596</a>         coerce_float=coerce_float,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=596'>597</a>         parse_dates=parse_dates,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=597'>598</a>         chunksize=chunksize,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=598'>599</a>     )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py:1557, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=1554'>1555</a> args = _convert_params(sql, params)
# -> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=1556'>1557</a> result = self.execute(*args)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=1557'>1558</a> columns = result.keys()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py:1402, in SQLDatabase.execute(self, *args, **kwargs)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=1400'>1401</a> """Simple passthrough to SQLAlchemy connectable"""
# -> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py?line=1401'>1402</a> return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py?line=399'>400</a>     _warn_with_version(message, version, wtype, stacklevel=3)
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py?line=400'>401</a> return fn(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3175, in Engine.execute(self, statement, *multiparams, **params)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3157'>3158</a> """Executes the given construct and returns a
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3158'>3159</a> :class:`_engine.CursorResult`.
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3159'>3160</a>
#    (...)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3172'>3173</a>
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3173'>3174</a> """
# -> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3174'>3175</a> connection = self.connect(close_with_result=True)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3175'>3176</a> return connection.execute(statement, *multiparams, **params)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3234, in Engine.connect(self, close_with_result)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3219'>3220</a> """Return a new :class:`_engine.Connection` object.
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3220'>3221</a>
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3221'>3222</a> The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3230'>3231</a>
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3231'>3232</a> """
# -> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3233'>3234</a> return self._connection_cls(self, close_with_result=close_with_result)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=91'>92</a> else:
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=92'>93</a>     self._dbapi_connection = (
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=93'>94</a>         connection
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=94'>95</a>         if connection is not None
# ---> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=95'>96</a>         else engine.raw_connection()
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=96'>97</a>     )
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=98'>99</a>     self._transaction = self._nested_transaction = None
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3313, in Engine.raw_connection(self, _connection)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3291'>3292</a> """Return a "raw" DBAPI connection from the connection pool.
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3292'>3293</a>
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3293'>3294</a> The returned object is a proxied version of the DBAPI
#    (...)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3310'>3311</a>
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3311'>3312</a> """
# -> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3312'>3313</a> return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3283, in Engine._wrap_pool_connect(self, fn, connection)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3281'>3282</a> if connection is None:
# -> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3282'>3283</a>     Connection._handle_dbapi_exception_noconnection(
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3283'>3284</a>         e, dialect, self
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3284'>3285</a>     )
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3285'>3286</a> else:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2117, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2115'>2116</a> elif should_wrap:
# -> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2116'>2117</a>     util.raise_(
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2117'>2118</a>         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2118'>2119</a>     )
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2119'>2120</a> else:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=206'>207</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=207'>208</a>     raise exception
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=208'>209</a> finally:
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # credit to
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     # as the __traceback__ object creates a cycle
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3278'>3279</a> try:
# -> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3279'>3280</a>     return fn()
#    <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=3280'>3281</a> except dialect.dbapi.Error as e:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=302'>303</a> """Return a DBAPI connection from the pool.
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=303'>304</a>
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=304'>305</a> The connection is instrumented such that when its
#    (...)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=307'>308</a>
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=308'>309</a> """
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=309'>310</a> return _ConnectionFairy._checkout(self)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=866'>867</a> if not fairy:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=867'>868</a>     fairy = _ConnectionRecord.checkout(pool)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=869'>870</a>     fairy._pool = pool
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=473'>474</a> @classmethod
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=474'>475</a> def checkout(cls, pool):
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=475'>476</a>     rec = pool._do_get()
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=476'>477</a>     try:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=144'>145</a>         with util.safe_reraise():
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=145'>146</a>             self._dec_overflow()
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=146'>147</a> else:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=68'>69</a>     if not self.warn_only:
# ---> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=69'>70</a>         compat.raise_(
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=70'>71</a>             exc_value,
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=71'>72</a>             with_traceback=exc_tb,
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=72'>73</a>         )
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=73'>74</a> else:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=206'>207</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=207'>208</a>     raise exception
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=208'>209</a> finally:
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # credit to
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     # as the __traceback__ object creates a cycle
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=141'>142</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=142'>143</a>     return self._create_connection()
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py?line=143'>144</a> except:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=253'>254</a> """Called by subclasses to create a new ConnectionRecord."""
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=255'>256</a> return _ConnectionRecord(self)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=369'>370</a> if connect:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=370'>371</a>     self.__connect()
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=371'>372</a> self.finalize_callback = deque()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:666, in _ConnectionRecord.__connect(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=664'>665</a>     with util.safe_reraise():
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=665'>666</a>         pool.logger.debug("Error on connect(): %s", e)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=666'>667</a> else:
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=667'>668</a>     # in SQLAlchemy 1.4 the first_connect event is not used by
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=668'>669</a>     # the engine, so this will usually not be set
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=68'>69</a>     if not self.warn_only:
# ---> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=69'>70</a>         compat.raise_(
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=70'>71</a>             exc_value,
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=71'>72</a>             with_traceback=exc_tb,
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=72'>73</a>         )
#      <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py?line=73'>74</a> else:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=206'>207</a> try:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=207'>208</a>     raise exception
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=208'>209</a> finally:
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # credit to
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     # as the __traceback__ object creates a cycle
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:661, in _ConnectionRecord.__connect(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=659'>660</a> self.starttime = time.time()
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=660'>661</a> self.dbapi_connection = connection = pool._invoke_creator(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py?line=661'>662</a> pool.logger.debug("Created new connection %r", connection)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py:590, in create_engine.<locals>.connect(connection_record)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py?line=588'>589</a>             return connection
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py?line=589'>590</a> return dialect.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=594'>595</a> def connect(self, *cargs, **cparams):
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=595'>596</a>     # inherits the docstring from interfaces.Dialect.connect
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=596'>597</a>     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py:353, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=351'>352</a> else:
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=352'>353</a>     self.connect()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py:664, in Connection.connect(self, sock)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=662'>663</a>         print(exc.traceback)
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=663'>664</a>     raise exc
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=665'>666</a> # If e is neither DatabaseError or IOError, It's a bug.
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=666'>667</a> # But raising AssertionError hides original error.
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py?line=667'>668</a> # So just reraise it.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '127.0.0.1' ([Errno 61] Connection refused)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# HttpStatusError                           Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py:807, in reconnect.<locals>.robustify.<locals>.wrapper(*args, **kws)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=803'>804</a> if (
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=804'>805</a>     getattr(r, "status_code", 200) != 200
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=805'>806</a> ):  # in case r is a json dict
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=806'>807</a>     raise HttpStatusError
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=807'>808</a> return r
#
# HttpStatusError:
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# /Users/zhouzhang/Code/Investment/xalpha_fund/import_xalpha.ipynb Cell 6' in <module>
# ----> <a href='vscode-notebook-cell:/Users/zhouzhang/Code/Investment/xalpha_fund/import_xalpha.ipynb#ch0000005?line=0'>1</a> xa.fundinfo("510018", **io)
#       <a href='vscode-notebook-cell:/Users/zhouzhang/Code/Investment/xalpha_fund/import_xalpha.ipynb#ch0000005?line=1'>2</a> yfd_zhongzhen500_c = xa.fundinfo('007029')
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py:551, in fundinfo.__init__(self, code, round_label, dividend_label, fetch, save, path, form, priceonly)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=545'>546</a> self._feeurl = (
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=546'>547</a>     "http://fund.eastmoney.com/f10/jjfl_" + code + ".html"
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=547'>548</a> )  # html url for trade fees info of certain fund
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=548'>549</a> self.priceonly = priceonly
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=550'>551</a> super().__init__(
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=551'>552</a>     code,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=552'>553</a>     fetch=fetch,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=553'>554</a>     save=save,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=554'>555</a>     path=path,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=555'>556</a>     form=form,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=556'>557</a>     round_label=label,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=557'>558</a>     dividend_label=dividend_label,
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=558'>559</a> )
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=560'>561</a> self.special = self.price[self.price["comment"] != 0]
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=561'>562</a> self.specialdate = list(self.special["date"])
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py:353, in basicinfo.__init__(self, code, fetch, save, path, form, round_label, dividend_label, value_label)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=350'>351</a>         logger.info("no saved copy of %s" % self.code)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=351'>352</a>         fetch = False
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=352'>353</a>         self._basic_init()
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=354'>355</a> if (save is True) and (fetch is False):
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=355'>356</a>     self.save(path, self.format)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py:574, in fundinfo._basic_init(self)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=571'>572</a>     self._hkfund_init()  # 中港互认基金处理
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=572'>573</a>     return
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=573'>574</a> self._page = rget(self._url)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=574'>575</a> if self._page.status_code == 404:
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/info.py?line=575'>576</a>     raise ParserFailure("Unrecognized fund, please check fund code you input.")
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py:816, in reconnect.<locals>.robustify.<locals>.wrapper(*args, **kws)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=810'>811</a> if count == tries - 1:
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=811'>812</a>     logger.error(
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=812'>813</a>         "Still wrong at fetching url: %s. after %s tries."
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=813'>814</a>         % (url, tries)
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=814'>815</a>     )
# --> <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=815'>816</a>     logger.error("Fails due to %s" % e.args[0])
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=816'>817</a>     raise e
#     <a href='file:///Users/zhouzhang/opt/anaconda3/lib/python3.8/site-packages/xalpha/cons.py?line=817'>818</a> time.sleep(0.5 * count)
#
# IndexError: tuple index out of range

# %%
yfd_zhongzhen500_c.info()
# Out:
# fund name: 易方达中证500ETF联接C
# fund code: 007029
# fund purchase fee: 0.0%
# fund redemption fee info: ['小于等于6天', '1.50%', '大于等于7天', '0.00%']

# %%
yfd_zhongzhen500_c.max_drawdown()
# Out:
# (Timestamp('2021-09-13 00:00:00'),
#  Timestamp('2022-04-26 00:00:00'),
#  -0.2912834257172443)

# %%
yfd_zhongzhen500_c.info.indexinfo()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/zhouzhang/Code/xalpha_fund/import_xalpha.ipynb Cell 5' in <module>
# ----> <a href='vscode-notebook-cell:/Users/zhouzhang/Code/xalpha_fund/import_xalpha.ipynb#ch0000004?line=0'>1</a> yfd_zhongzhen500_c.info.indexinfo()
#
# AttributeError: 'function' object has no attribute 'indexinfo'

# %%
yfd_zhongzhen500_c.get_stock_holdings(2021, 1)
